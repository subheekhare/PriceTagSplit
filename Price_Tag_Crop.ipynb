# %%
# !nvidia-smi
# Out:
# Sun Dec 15 05:10:34 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   49C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
import torch

# %%
print(torch.__version__)
# Out:
# 2.5.1+cu121

# %%
range_ = torch.arange(0, 10, 2)
print(range_)
# Out:
# tensor([0, 2, 4, 6, 8])

# %%
torch.matmul(range_, range_)
# Out:
# tensor(120)

# %%
tensor_a=torch.tensor([[1, 2],
                      [3, 4],
                       [5,6] ])
tensor_b=torch.tensor([[1, 2],
                        [3, 4],
                        [5,6] ])

torch.matmul(tensor_a, tensor_b.T)
# Out:
# tensor([[ 5, 11, 17],
#         [11, 25, 39],
#         [17, 39, 61]])

# %%
from google.colab.patches import cv2_imshow

# %%
pip list
# Out:
# Package                            Version
# ---------------------------------- -------------------
# absl-py                            1.4.0
# accelerate                         1.1.1
# aiohappyeyeballs                   2.4.4
# aiohttp                            3.11.10
# aiosignal                          1.3.1
# alabaster                          1.0.0
# albucore                           0.0.19
# albumentations                     1.4.20
# altair                             5.5.0
# annotated-types                    0.7.0
# anyio                              3.7.1
# argon2-cffi                        23.1.0
# argon2-cffi-bindings               21.2.0
# array_record                       0.5.1
# arviz                              0.20.0
# astropy                            6.1.7
# astropy-iers-data                  0.2024.12.9.0.36.21
# astunparse                         1.6.3
# async-timeout                      4.0.3
# atpublic                           4.1.0
# ...

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow, cv2_imwrite

input_image = cv2.imread("/content/drive/MyDrive/ColabNotebooks/barcode-price-tag-1000x1000.jpeg")

# input_image.shape[:2]

height, width = input_image.shape[:2]
# print("Image Dimensions: ", width, "x", height)



# x, y, w, h = 30, 5, 185, 185
# region_of_interest = input_image[y:y+h, x:x+w]
# cv2_imshow(region_of_interest)

# x, y, w, h = 30,195, 185, 185
# region_of_interest_r21 = input_image[, x:x+w]
# cv2_imshow(region_of_interest_r21)
input_image1=input_image[5:795, 30:580]
input_image1.shape
# cv2_imshow(input_image1)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-95-ea5ecfe98b41> in <cell line: 3>()
#       1 import cv2
#       2 import numpy as np
# ----> 3 from google.colab.patches import cv2_imshow, cv2_imwrite
#       4
#       5 input_image = cv2.imread("/content/drive/MyDrive/ColabNotebooks/barcode-price-tag-1000x1000.jpeg")
#
# ImportError: cannot import name 'cv2_imwrite' from 'google.colab.patches' (/usr/local/lib/python3.10/dist-packages/google/colab/patches/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
input_image.shape
# Out:
# (800, 610, 3)

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

input_image = cv2.imread("/content/drive/MyDrive/ColabNotebooks/barcode-price-tag-1000x1000.jpeg")

input_image1=input_image[5:795, 30:580]
# cv2_imshow(input_image1)

# x = 0
# y  = 0
# w = 182


# xpad=3
# ypad=3
# dy=0
# for i in range(4):
#   dx = x+w
#   dy = y+w+dy
  # input_image11=input_image1[x:dx, y:dy]
  #cv2.imwrite("/content/drive/MyDrive/ColabNotebooks/input_image11.jpg", input_image11)

input_image11=input_image1[0:182, 0:182]
cv2_imshow(input_image11)

input_image12=input_image1[0:185, 187:368]
cv2_imshow(input_image12)

input_image13=input_image1[0:185, 369:580]
cv2_imshow(input_image13)

input_image21=input_image1[190:375, 0:185]
# cv2_imshow(input_image21)

input_image22=input_image1[190:390, 190:365]
# cv2_imshow(input_image22)

input_image23=input_image1[190:390, 370:580]
# cv2_imshow(input_image23)

input_image31=input_image1[400:590, 0:185]
# cv2_imshow(input_image31)

input_image32=input_image1[400:590, 190:365]
# cv2_imshow(input_image32)

input_image33=input_image1[400:590, 370:580]
# cv2_imshow(input_image33)

input_image41=input_image1[600:795, 0:185]
# cv2_imshow(input_image41)

input_image42=input_image1[600:795, 190:365]
# cv2_imshow(input_image42)

input_image43=input_image1[600:795, 370:580]
# cv2_imshow(input_image43)
# Out:
# <PIL.Image.Image image mode=RGB size=182x182>
# <PIL.Image.Image image mode=RGB size=181x185>
# <PIL.Image.Image image mode=RGB size=181x185>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

input_image = cv2.imread("/content/drive/MyDrive/ColabNotebooks/barcode-price-tag-1000x1000.jpeg")

input_image1=input_image[5:795, 30:580]

x = 0
y  = 0
w = 187
h = 182

xpad=13
ypad=2
dy=0
dx=0
for i in range(4):
  # input_image1=input_image[5:795, 30:580]

  for j in range(3):
    dx = x+w
    dy = y+h
    # print(dx, dx)
    input_image11=input_image1[x:dx, y:dy]

    path=f"/content/drive/MyDrive/ColabNotebooks/split_tags/input_image{i}{j}.jpeg"
    # cv2.imwrite(path, input_image11)
    cv2_imshow(input_image11)
    y=dy+ypad
    print(x, dx, y, dy)
  x=dx+xpad
  y=0
  w = 187
  h = 182
  print(x)
# Out:
# <PIL.Image.Image image mode=RGB size=182x187>
# 0 187 184 182
# <PIL.Image.Image image mode=RGB size=182x187>
# 0 187 368 366
# <PIL.Image.Image image mode=RGB size=182x187>
# 0 187 552 550
# 200
# <PIL.Image.Image image mode=RGB size=182x187>
# 200 387 184 182
# <PIL.Image.Image image mode=RGB size=182x187>
# 200 387 368 366
# <PIL.Image.Image image mode=RGB size=182x187>
# 200 387 552 550
# 400
# <PIL.Image.Image image mode=RGB size=182x187>
# 400 587 184 182
# <PIL.Image.Image image mode=RGB size=182x187>
# 400 587 368 366
# <PIL.Image.Image image mode=RGB size=182x187>
# 400 587 552 550
# 600
# <PIL.Image.Image image mode=RGB size=182x187>
# 600 787 184 182
# <PIL.Image.Image image mode=RGB size=182x187>
# 600 787 368 366
# <PIL.Image.Image image mode=RGB size=182x187>
# 600 787 552 550
# 800

# %%
import cv2
import math
import numpy as np
from google.colab.patches import cv2_imshow

input_image = cv2.imread("/content/drive/MyDrive/ColabNotebooks/assignment-2.jpg")
# 990, 700

input_image1=input_image[10:985, 10:680]
# print(input_image1.shape)
x = 0
y  = 0
w = math.floor(input_image1.shape[0]/6)
h = math.floor(input_image1.shape[1]/3)

xpad=2
ypad=2
dy=0
dx=0
for i in range(6):
  for j in range(3):
    dx = x+w
    dy = y+h
    # print(dx, dx)
    input_image11=input_image1[x:dx, y:dy]

    path=f"/content/drive/MyDrive/ColabNotebooks/split_tags/input_image{i}{j}.jpeg"
    cv2.imwrite(path, input_image11)
    cv2_imshow(input_image11)
    y=dy+ypad
    # print(x, dx, y, dy)
  x=dx+xpad
  y=0
  w = math.floor(input_image1.shape[0]/6)
  h = math.floor(input_image1.shape[1]/3)
  # print(x)
# Out:
# (975, 670, 3)
# <PIL.Image.Image image mode=RGB size=223x162>
# 0 162 225 223
# <PIL.Image.Image image mode=RGB size=223x162>
# 0 162 450 448
# <PIL.Image.Image image mode=RGB size=220x162>
# 0 162 675 673
# 164
# <PIL.Image.Image image mode=RGB size=223x162>
# 164 326 225 223
# <PIL.Image.Image image mode=RGB size=223x162>
# 164 326 450 448
# <PIL.Image.Image image mode=RGB size=220x162>
# 164 326 675 673
# 328
# <PIL.Image.Image image mode=RGB size=223x162>
# 328 490 225 223
# <PIL.Image.Image image mode=RGB size=223x162>
# 328 490 450 448
# <PIL.Image.Image image mode=RGB size=220x162>
# 328 490 675 673
# 492
# <PIL.Image.Image image mode=RGB size=223x162>
# 492 654 225 223
# <PIL.Image.Image image mode=RGB size=223x162>
# 492 654 450 448
# <PIL.Image.Image image mode=RGB size=220x162>
# 492 654 675 673
# 656
# <PIL.Image.Image image mode=RGB size=223x162>
# 656 818 225 223
# <PIL.Image.Image image mode=RGB size=223x162>
# 656 818 450 448
# ...
