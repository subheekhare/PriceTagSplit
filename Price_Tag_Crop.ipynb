# %%
import cv2
import math
import numpy as np
from google.colab.patches import cv2_imshow

input_image = cv2.imread("/content/drive/MyDrive/ColabNotebooks/assignment-2.jpg")
# 990, 700

input_image1=input_image[10:985, 10:680]
# print(input_image1.shape)
x = 0
y  = 0
w = math.floor(input_image1.shape[0]/6)
h = math.floor(input_image1.shape[1]/3)

xpad=2
ypad=2
dy=0
dx=0
for i in range(6):
  for j in range(3):
    dx = x+w
    dy = y+h
    # print(dx, dx)
    input_image11=input_image1[x:dx, y:dy]

    path=f"/content/drive/MyDrive/ColabNotebooks/split_tags/input_image{i}{j}.jpeg"
    cv2.imwrite(path, input_image11)
    cv2_imshow(input_image11)
    y=dy+ypad
    # print(x, dx, y, dy)
  x=dx+xpad
  y=0
  w = math.floor(input_image1.shape[0]/6)
  h = math.floor(input_image1.shape[1]/3)
  # print(x)
# Out:
# (975, 670, 3)
# <PIL.Image.Image image mode=RGB size=223x162>
# 0 162 225 223
# <PIL.Image.Image image mode=RGB size=223x162>
# 0 162 450 448
# <PIL.Image.Image image mode=RGB size=220x162>
# 0 162 675 673
# 164
# <PIL.Image.Image image mode=RGB size=223x162>
# 164 326 225 223
# <PIL.Image.Image image mode=RGB size=223x162>
# 164 326 450 448
# <PIL.Image.Image image mode=RGB size=220x162>
# 164 326 675 673
# 328
# <PIL.Image.Image image mode=RGB size=223x162>
# 328 490 225 223
# <PIL.Image.Image image mode=RGB size=223x162>
# 328 490 450 448
# <PIL.Image.Image image mode=RGB size=220x162>
# 328 490 675 673
# 492
# <PIL.Image.Image image mode=RGB size=223x162>
# 492 654 225 223
# <PIL.Image.Image image mode=RGB size=223x162>
# 492 654 450 448
# <PIL.Image.Image image mode=RGB size=220x162>
# 492 654 675 673
# 656
# <PIL.Image.Image image mode=RGB size=223x162>
# 656 818 225 223
# <PIL.Image.Image image mode=RGB size=223x162>
# 656 818 450 448
# ...
